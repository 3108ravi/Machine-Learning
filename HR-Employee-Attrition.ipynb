# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("HR-Employee-Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Overview of Data

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.drop(["MonthlyRate","DailyRate","HourlyRate","EmployeeNumber","EmployeeCount","StandardHours"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EnvironmentSatisfaction   1470 non-null   int64
#  8   Gender                    1470 non-null   object
#  9   JobInvolvement            1470 non-null   int64
#  10  JobLevel                  1470 non-null   int64
#  11  JobRole                   1470 non-null   object
#  12  JobSatisfaction           1470 non-null   int64
#  13  MaritalStatus             1470 non-null   object
# ...

# %% [markdown]
# # Analysis and Visualization

# %%
df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# # Total number of employees in oragnization is 1470 apart from them 1233 employees stayed in the organization and while 237 left it.

# %%
plt.pie(df["Attrition"].value_counts(),autopct="%0.2f%%",labels=["NO","YES"])
plt.show()

# %% [markdown]
# # attrition rate of organization is 16.12%

# %%
plt.figure(figsize=(5,5))
df["Gender"].value_counts().plot(kind="pie",autopct="%0.2f%%")
plt.title("Gender")
plt.show()
df["Gender"].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %% [markdown]
# # There are 60% male and 40% female employees are in the organization.

# %% [markdown]
# # Age

# %%
plt.figure(figsize=(8,8))
sns.displot(x=df["Age"],color="Blue",label="Age")
plt.axvline(x=df["Age"].mean(),color="Red",label="Mean age:36.923")
plt.legend()
plt.title("Distribution of age")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.countplot(df["Age"],hue=df["Attrition"])
plt.show()

# %% [raw]
# from above two graphs we can see that most of the employees are from age group of 26 to 46
# while average of employees is 37
# while most of the employees are tends to leave the organization in their early stage of career.

# %% [markdown]
# # SALARY

# %%
df["MonthlyIncome"].mean()
# Out:
# 6502.931292517007

# %%
plt.figure(figsize=(8,5))
sns.distplot(x=df["MonthlyIncome"],label="Monthly Income")
plt.axvline(x=df["MonthlyIncome"].mean(),color="Red",linestyle="--",label="Avge monthly income")
plt.legend()
plt.title("Distribution of Monthly Income")
plt.show()

# %% [markdown]
# # Department

# %%
df["Department"].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Department"],hue=df["Gender"])
plt.show()

# %% [markdown]
# # Above Graph represents count of the male and female employees from each departments

# %%
plt.figure(figsize=(10,5))
sns.countplot(df["Department"],hue=df["BusinessTravel"])
plt.show()

# %% [raw]
# above graph represents the number of traveling employees from each department

# %% [markdown]
# # Business Travel

# %%
len(df.loc[(df["Attrition"]=="Yes") & (df["BusinessTravel"]=="Non-Travel")])
# Out:
# 12

# %%
len(df.loc[(df["Attrition"]=="Yes") & (df["BusinessTravel"]=="Travel_Frequently")])
# Out:
# 69

# %%
len(df.loc[(df["Attrition"]=="Yes") & (df["BusinessTravel"]=="Travel_Rarely")])
# Out:
# 156

# %%
len(df.loc[(df["Attrition"]=="Yes")])
# Out:
# 237

# %%
sns.countplot(x=df["BusinessTravel"],hue=df["Attrition"])
plt.show()

# %% [raw]
# Apart from 237 attrited employees 156 employees were traveled rarely 69 employees were travelling frequently and 12 employees were from non-travel class
# which indicates that there is no tend between employee travel and attrition.

# %%
plt.figure(figsize=(5,5))
df["BusinessTravel"].value_counts().plot(kind="pie",autopct="%0.2f%%")
plt.title("Employee Business Travel")
plt.show()
df["BusinessTravel"].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(df["BusinessTravel"],hue=df["Attrition"])
plt.show()

# %% [raw]
# Pie chart shows the distribution of all employees in three class named as non-travel,travel frequently and travel rarely while bar graph represents the attrition comparison from these travel class

# %% [markdown]
# # Education Field

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["EducationField"],hue=df["Gender"])
plt.show()
print(df["EducationField"].value_counts())
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %% [raw]
# above graph represents educational background of male and female employees within organization

# %% [markdown]
# # Distance from home

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["DistanceFromHome"],hue=df["Attrition"])
plt.show()

# %%
df["DistanceFromHome"].mean()
# Out:
# 9.19251700680272

# %%
plt.figure(figsize=(8,5))
sns.distplot(x=df["DistanceFromHome"],color="Blue",label="DistanceFromHome")
plt.axvline(x=df["DistanceFromHome"].mean(),color="Red",label="Avg distance from home: 9.19")
plt.legend()
plt.title("Distance from Home")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.jointplot(df["DistanceFromHome"],df["YearsAtCompany"],kind="kde")
plt.show()

# %% [raw]
# Above figures shows that average distance between office from 9.19 km while majority of  the employees stays within range of 10km.
# also there is clear trend which shows that employees who lives away from the office are tends to leave the organisation mmore than those who lives nearby

# %% [markdown]
# # Education

# %%
plt.figure(figsize=(8,5))
sns.countplot(df["Education"])
plt.show()
print("Education\n1 'Below College'\n2'College'\n3'bachelor'\n4'Very High'")
# Out:
# Education
# 1 'Below College'
# 2'College'
# 3'bachelor'
# 4'Very High'

# %% [raw]
# Above Graph incdicates that employee with low enoviroment satisfaction have more attrition rate than others.

# %% [markdown]
# # JobInvolvement

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["JobInvolvement"],hue=df["Attrition"])
plt.show()

# %%
print("JobInvolvement\n1 'Low'\n2'Medium'\n3'High'\n4'Very High'")
# Out:
# JobInvolvement
# 1 'Low'
# 2'Medium'
# 3'High'
# 4'Very High'

# %% [raw]
# ABove graph clearly indicated that employee with low level of job envolvement leavs more often that others

# %% [markdown]
# # JOBlevel

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["JobLevel"],hue=df["Attrition"])
plt.show()

# %% [raw]
# Above graph shows that employee who are in their early stage of career or have have low job leave more often

# %% [markdown]
# # JOBRole

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["JobRole"],hue=df["Attrition"])
plt.show()
print(df["JobRole"].value_counts())
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %% [raw]
# Above graph shows the attrition rate with respect to the job roles and number of employees within the organization with that role

# %% [markdown]
# # JOBSatisfaction

# %%
plt.figure(figsize=(5,5))
plt.pie(df["JobSatisfaction"].value_counts(),autopct="%0.2f%%",labels=["Very low","Low","Medium","High"])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["JobSatisfaction"],hue=df["Attrition"])
plt.show()

# %%
print("JobSatisfaction\n1 'Low'\n2'Medium'\n3'High'\n4'Very High'")
# Out:
# JobSatisfaction
# 1 'Low'
# 2'Medium'
# 3'High'
# 4'Very High'

# %% [raw]
# Above graph indicates that employee with low job satisfaction have more attrition rate that the others

# %% [markdown]
# # MaritalStatus

# %%
plt.figure(figsize=(15,5))
sns.countplot(df["MaritalStatus"],hue=df["Attrition"])
plt.show()
df["MaritalStatus"].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %% [raw]
# Single employee have more than attrition rate than of the married an divorced

# %%
plt.pie(df["MaritalStatus"].value_counts(),autopct="%0.2f%%",labels=["Married","Single","Divorced"])
plt.show()

# %% [markdown]
# # Number of companies worked

# %%
df["NumCompaniesWorked"].value_counts()
# Out:
# 1    521
# 0    197
# 3    159
# 2    146
# 4    139
# 7     74
# 6     70
# 5     63
# 9     52
# 8     49
# Name: NumCompaniesWorked, dtype: int64

# %%
plt.figure(figsize=(20,10))
sns.countplot(df["NumCompaniesWorked"],hue=df["Attrition"])
plt.show()

# %% [raw]
# Employee who had worked in 4 or more than 4 companies before have more attrition rate compared to others

# %% [markdown]
# # OverTime

# %%
plt.figure(figsize=(20,10))
sns.countplot(df["OverTime"],hue=df["Attrition"])
plt.show()
df["OverTime"].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [raw]
# Employee who do overtime have more attrition rate than who doesn't

# %% [markdown]
# # WorkLifeBalance

# %%
plt.figure(figsize=(20,10))
sns.countplot(df["WorkLifeBalance"],hue=df["Attrition"])
plt.grid()
plt.show()

# %% [raw]
# employee who have lowest & highest work life balance have more attrition rate than other

# %% [markdown]
# # PercentSalaryHike

# %%
plt.figure(figsize=(20,10))
sns.countplot(df["PercentSalaryHike"],hue=df["Attrition"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(x=df["PercentSalaryHike"],color="Blue",label="Percent Salary Hike")
plt.axvline(x=df["PercentSalaryHike"].mean(),color="Red",label="Avg Percent Salary Hike:15.20 ")
plt.legend()
plt.title("Percent Salary Hike")
plt.show()

# %% [raw]
# Above graph represents us that average salary hike in this organization is around 15% while majority of employee gets salary hike between 10%-15%

# %% [markdown]
# # TotalWorkingYears

# %%
plt.figure(figsize=(20,8))
sns.countplot(df["TotalWorkingYears"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(x=df["TotalWorkingYears"],color="Blue",label="TotalWorkingYears")
plt.axvline(x=df["TotalWorkingYears"].mean(),color="Red",label="Avg total working hours:11.27 ")
plt.legend()
plt.title("TotalWorkingYears")
plt.show()

# %% [raw]
# Above graph represents showcase that average working experience of the employee in organization is around 11 years.

# %% [markdown]
# # YearsAtCompany

# %%
plt.figure(figsize=(20,8))
sns.countplot(df["YearsAtCompany"])
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(x=df["YearsAtCompany"],color="Blue",label="Years At Company")
plt.axvline(x=df["YearsAtCompany"].mean(),color="Red",label="Avg years at company:7 ")
plt.legend()
plt.title("YearsAtCompany")
plt.show()

# %% [raw]
# above graph represents that employee spend average of 7 years at the company

# %%
df.corr()
# Out:
#                                Age  DistanceFromHome  Education  \
# Age                       1.000000         -0.001686   0.208034
# DistanceFromHome         -0.001686          1.000000   0.021042
# Education                 0.208034          0.021042   1.000000
# EnvironmentSatisfaction   0.010146         -0.016075  -0.027128
# JobInvolvement            0.029820          0.008783   0.042438
# JobLevel                  0.509604          0.005303   0.101589
# JobSatisfaction          -0.004892         -0.003669  -0.011296
# MonthlyIncome             0.497855         -0.017014   0.094961
# NumCompaniesWorked        0.299635         -0.029251   0.126317
# PercentSalaryHike         0.003634          0.040235  -0.011111
# PerformanceRating         0.001904          0.027110  -0.024539
# RelationshipSatisfaction  0.053535          0.006557  -0.009118
# StockOptionLevel          0.037510          0.044872   0.018422
# TotalWorkingYears         0.680381          0.004628   0.148280
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True, linewidth=0.5)
plt.show()

# %% [markdown]
# # Data preparation for ML

# %% [markdown]
# # Converting categorical data into numeric data

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

# %%
colname=df.select_dtypes(object).columns
colname
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
df[colname]=oe.fit_transform(df[colname])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      41        1.0             2.0         2.0                 1          2
# 1      49        0.0             1.0         1.0                 8          1
# 2      37        1.0             2.0         1.0                 2          2
# 3      33        0.0             1.0         1.0                 3          4
# 4      27        0.0             2.0         1.0                 2          1
# ...   ...        ...             ...         ...               ...        ...
# 1465   36        0.0             1.0         1.0                23          2
# 1466   39        0.0             2.0         1.0                 6          1
# 1467   27        0.0             2.0         1.0                 4          3
# 1468   49        0.0             1.0         2.0                 2          3
# 1469   34        0.0             2.0         1.0                 8          3
#
# ...

# %%
features=df.iloc[:,2:]
features["Age"]=df.iloc[:,0:1]
target=df.iloc[:,1]

# %%
features
# Out:
#       BusinessTravel  Department  DistanceFromHome  Education  EducationField  \
# 0                2.0         2.0                 1          2             1.0
# 1                1.0         1.0                 8          1             1.0
# 2                2.0         1.0                 2          2             4.0
# 3                1.0         1.0                 3          4             1.0
# 4                2.0         1.0                 2          1             3.0
# ...              ...         ...               ...        ...             ...
# 1465             1.0         1.0                23          2             3.0
# 1466             2.0         1.0                 6          1             3.0
# 1467             2.0         1.0                 4          3             1.0
# 1468             1.0         2.0                 2          3             3.0
# 1469             2.0         1.0                 8          3             3.0
#
# ...

# %%
target
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       0.0
#        ...
# 1465    0.0
# 1466    0.0
# 1467    0.0
# 1468    0.0
# 1469    0.0
# Name: Attrition, Length: 1470, dtype: float64

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(features,target,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVC
svm=SVC()

# %%
from sklearn.metrics import classification_report,accuracy_score

# %%
cr=classification_report
ac=accuracy_score

# %%
svm.fit(xtrain,ytrain)
ypred=svm.predict(xtest)
print(classification_report(ytest,ypred))
ac(ytest,ypred)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93       255
#          1.0       0.00      0.00      0.00        39
#
#     accuracy                           0.87       294
#    macro avg       0.43      0.50      0.46       294
# weighted avg       0.75      0.87      0.81       294
# 0.8673469387755102

# %%
svm.score(xtrain,ytrain)
# Out:
# 0.8316326530612245
